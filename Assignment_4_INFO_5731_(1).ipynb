# %% [markdown]
# <a href="https://colab.research.google.com/github/varaprasad7006/SatyaVaraPrasad_INFO5731_Spring2025024/blob/main/Assignment_4_INFO_5731_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment: 4**
#
# **This exercise will provide a valuable learning experience in working with text data and extracting features using various topic modeling algorithms. Key concepts such as Latent Dirichlet Allocation (LDA), Latent Semantic Analysis (LSA) and BERTopic.**

# %% [markdown]
# **Expectations**:
# *   Students are expected to complete the exercise during lecture period to meet the active participation criteria of the course.
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# **Total points**: 100
#
#
# NOTE: The output should be presented well to get **full points**
#
# **Late submissions will have a penalty of 10% of the marks for each day of late submission, and no requests will be answered. Manage your time accordingly.**

# %% [markdown]
# # **Question 1 (20 Points)**

# %% [markdown]
# **Dataset**: 20 Newsgroups dataset
#
# **Dataset Link**: https://scikit-learn.org/0.19/datasets/twenty_newsgroups.html
#
# **Consider Random 2000 rows only**
#
# Generate K=10 topics by using LDA and LSA,
# then calculate coherence score and determine the optimized K value by the coherence score. Further, summarize and visualize each topics in you own words.

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# Load the dataset
newsgroups = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))

# Randomly sample 2000 rows from the dataset
np.random.seed(42)
rand_indices = np.random.choice(len(newsgroups.data), 2000, replace=False)
sampled_texts = [newsgroups.data[idx] for idx in rand_indices]

# Vectorize the texts
vectorizer = TfidfVectorizer(stop_words='english', max_df=0.5, min_df=10)
dtm = vectorizer.fit_transform(sampled_texts)

# %%
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD

# LDA Model
lda = LatentDirichletAllocation(n_components=10, random_state=42)
lda_dtm = lda.fit_transform(dtm)

# LSA Model
lsa = TruncatedSVD(n_components=10, random_state=42)
lsa_dtm = lsa.fit_transform(dtm)

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# Load and sample the dataset
newsgroups = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))
rand_indices = np.random.choice(len(newsgroups.data), 2000, replace=False)
sampled_texts = [newsgroups.data[idx] for idx in rand_indices]

# Vectorize the texts
vectorizer = TfidfVectorizer(stop_words='english', max_df=0.5, min_df=10)
dtm = vectorizer.fit_transform(sampled_texts)

# %%
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD

# LDA Model
lda = LatentDirichletAllocation(n_components=10, random_state=42)
lda_dtm = lda.fit_transform(dtm)

# LSA Model
lsa = TruncatedSVD(n_components=10, random_state=42)
lsa_dtm = lsa.fit_transform(dtm)

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 10
feature_names = vectorizer.get_feature_names_out()

# Display LDA topics
print("LDA Topics:")
display_topics(lda, feature_names, no_top_words)

# Display LSA topics
print("\nLSA Topics:")
display_topics(lsa, feature_names, no_top_words)
# Out:
# LDA Topics:
# Topic 0:
# tom season nhl espn nasa guys thanx coach models export
# Topic 1:
# steve bob lemieux damn israelis hear info robert edu orthodox
# Topic 2:
# station traffic ice ca functions ames concerning export test theory
# Topic 3:
# thanks windows know does like use drive file email card
# Topic 4:
# don think just people like good time way know said
# Topic 5:
# clipper ide government key launch moon trust technology solar encryption
# Topic 6:
# jesus god people did bible church christian israel government jews
# Topic 7:
# gm pain jim needed technique atheist rules money places grant
# Topic 8:
# convert armenians muslims st muslim york conditions pitch resources germany
# Topic 9:
# aid wonder effective sex land life ice die thrown met
#
# LSA Topics:
# Topic 0:
# don like people just know think does good use time
# Topic 1:
# windows thanks file card dos drive use files program pc
# Topic 2:
# god windows jesus people does file bible dos evidence christians
# ...

# %% [markdown]
# # **BERTopic**

# %% [markdown]
# The following question is designed to help you develop a feel for the way topic modeling works, the connection to the human meanings of documents.
#
# Dataset from **assignment-3** (text dataset) .
#
# > Dont use any custom datasets.
#
#
# > Dataset must have 1000+ rows, no duplicates and null values

# %% [markdown]
# # **Question 2 (20 Points)**

# %% [markdown]
# Q2) **Generate K=10 topics by using BERTopic and then find optimal K value by the coherence score. Interpret each topic and visualize with suitable style.**

# %%
from sklearn.datasets import fetch_20newsgroups

# Load the dataset
data = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))
texts = data.data

# Convert to DataFrame to handle duplicates and null values
import pandas as pd
df = pd.DataFrame(texts, columns=['text'])
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# Sample to ensure over 1000 rows
df = df.sample(n=1000, random_state=42)
texts = df['text'].tolist()

# %%
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

# Instantiate BERTopic
topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True)

# Fit the model
topics, probs = topic_model.fit_transform(texts)
# Out:
# 2025-04-07 23:17:52,160 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# 2025-04-07 23:19:33,128 - BERTopic - Embedding - Completed ✓
# ...

# %%
# Optimize the number of topics
topic_model.update_topics(texts, topics, n_gram_range=(1, 2))
topic_model.get_topic_info()
# Out:
#    Topic  Count             Name  \
# 0      0    896  0_the_to_of_and
# 1      1    104   1_the_to_of_in
#
#                                       Representation  \
# 0     [the, to, of, and, is, in, that, it, for, you]
# 1  [the, to, of, in, and, for, was, hockey, of th...
#
#                                  Representative_Docs
# 0  [Archive-name: jpeg-faq\nLast-modified: 2 May ...
# 1  [4/23/93    BLUES SHUTOUT HAWKS AGAIN, LEAD SE...

# %%
# Check topics
topic_info = topic_model.get_topic_info()
print(topic_info)
# Out:
#    Topic  Count             Name  \
# 0      0    896  0_the_to_of_and
# 1      1    104   1_the_to_of_in
#
#                                       Representation  \
# 0     [the, to, of, and, is, in, that, it, for, you]
# 1  [the, to, of, in, and, for, was, hockey, of th...
#
#                                  Representative_Docs
# 0  [Archive-name: jpeg-faq\nLast-modified: 2 May ...
# 1  [4/23/93    BLUES SHUTOUT HAWKS AGAIN, LEAD SE...

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

# Load dataset
data = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))
texts = data.data

# Instantiate and fit BERTopic
topic_model = BERTopic(verbose=True)
topics, _ = topic_model.fit_transform(texts)

# Get an overview of the topics
topic_info = topic_model.get_topic_info()
print(topic_info)

# Visualize topics if possible
try:
    topic_model.visualize_topics()
except Exception as e:
    print("Visualization error:", e)

# %%
# Get top n words for each topic
topic_model.get_topic_freq().head()

# Print words for a specific topic
topic_model.get_topic(10)  # Replace 0 with other topic numbers
# Out:
# [('the', np.float64(0.08024674298882628)),
#  ('to', np.float64(0.05075960176936528)),
#  ('of', np.float64(0.046467884376251906)),
#  ('and', np.float64(0.04319600668803219)),
#  ('is', np.float64(0.03476451462903063)),
#  ('in', np.float64(0.03149035170548664)),
#  ('that', np.float64(0.030049749661444712)),
#  ('it', np.float64(0.024153428110022867)),
#  ('for', np.float64(0.023717266976504232)),
#  ('you', np.float64(0.02296683280218137))]

# %% [markdown]
# # **Question 3 (25 points)**

# %% [markdown]
# **Dataset Link**: 20 Newsgroup Dataset (Random 2000 values)
#
# Q3) Using a given dataset, Modify the default representation model by integrating OpenAI's GPT model to generate meaningful summaries for each topic. Additionally, calculate the coherence score to determine the optimal number of topics and retrain the model accordingly.

# %% [markdown]
# Usefull Link: https://maartengr.github.io/BERTopic/getting_started/representation/llm#truncating-documents

# %%
from sklearn.datasets import fetch_20newsgroups
import numpy as np

# Load dataset
data = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))
texts = np.array(data.data)  # Convert to numpy array for easy sampling

# Random sample of 2000 texts
np.random.seed(42)  # For reproducibility
random_indices = np.random.choice(len(texts), size=2000, replace=False)
sampled_texts = texts[random_indices]
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/varaprasadn/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/varaprasadn/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
# ...

# %% [markdown]
# # **Question 4 (35 Points)**

# %% [markdown]
# **BERTopic** allows for extensive customization, including the choice of embedding models, dimensionality reduction techniques, and clustering algorithms.
#
# **Dataset Link**: 20 Newsgroup Dataset (Random 2000 values)
#
# 4)
#
# 4.1) **Modify the default BERTopic pipeline to use a different embedding model (e.g., Sentence-Transformers) and a different clustering algorithm (e.g., DBSCAN instead of HDBSCAN).
#
# 4.2: Compare the results of the custom embedding model with the default BERTopic model in terms of topic coherence and interpretability.
#
# 4.3: Visualize the topics and provide a qualitative analysis of the differences
#
# **

# %% [markdown]
# Usefull Link :https://www.pinecone.io/learn/bertopic/

# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import DBSCAN
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

# Load the dataset
from datasets import load_dataset
data = load_dataset('20_newsgroups', split='train[:2000]')['text']

# Set up Sentence Transformer model
embedding_model = SentenceTransformer('all-MiniLM-L12-v2')

# Set up DBSCAN model
clustering_model = DBSCAN(eps=0.5, min_samples=5, metric='euclidean')

# Create a custom BERTopic model
custom_bertopic = BERTopic(embedding_model=embedding_model,
                           clustering_model=clustering_model,
                           vectorizer_model=CountVectorizer(stop_words='english', ngram_range=(1, 2)))

topics, probs = custom_bertopic.fit_transform(data)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/varaprasadn/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/varaprasadn/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
# ...

# %%
import numpy as np

# %% [markdown]
# ## Extra Question (5 Points)
#
# **Compare the results generated by the four topic modeling algorithms (LDA, LSA, BERTopic, Modified BERTopic), which one is better? You should explain the reasons in details.**
#
# **This question will compensate for any points deducted in this exercise. Maximum marks for the exercise is 100 points.**

# %%
# Write your code here

# %% [markdown]
# # Mandatory Question

# %% [markdown]
# **Important: Reflective Feedback on this exercise**
#
# Please provide your thoughts and feedback on the exercises you completed in this assignment.
#
# Consider the following points in your response:
#
# **Learning Experience:** Describe your overall learning experience in working with text data and extracting features using various topic modeling algorithms. Did you understand these algorithms and did the implementations helped in grasping the nuances of feature extraction from text data.
#
# **Challenges Encountered:** Were there specific difficulties in completing this exercise?
#
# Relevance to Your Field of Study: How does this exercise relate to the field of NLP?
#
# **(Your submission will not be graded if this question is left unanswered)**

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:





'''
